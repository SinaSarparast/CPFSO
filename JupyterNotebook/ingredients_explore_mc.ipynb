# %%
# work with ingredients to identify most common words /good candidates for stemming and classifying
import re
# Load in the pandas library
import pandas as pd
import numpy as np
import nltk
import pickle
#make sure these library items are downloaded
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
#nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
#from nltk.corpus import wordnet as wn

with open('./Dataset/unique_ingredients.txt', 'r') as file:
     content = file.readlines()
file.closed

ingredientwords = {}
print('We are starting with %d unique ingredients') % len(content)
#print(content)

with open('./Dataset/unique_cuisines.txt', 'r') as file:
     cuisinescontent = file.readlines()
file.closed

#manually adding country related words in case these are significant
cuisines = ["Belgian"]
for cuisine in cuisinescontent:
    cuisines.append(str(cuisine))

print("here are all the cuisines")
print cuisines

ingredienttowords={}

for ingredient in content:
    print ingredient
    words = re.findall(r'\w+', ingredient)
    print words
    ingredienttowords.setdefault(ingredient,[]).append(words)
    
    #for word in words:
        #ingredient_tuple =  words,word
        #will set dict[key]=default if key is not already in dict.
        #ingredienttowords.setdefault(ingredient,[]).append(ingredient_tuple)
        
        
print("This maps all ingredients to the unique words that make them up")
print len(ingredienttowords)
print ingredienttowords

#write the ingredientwords down to a pkl file
#dictionary maps every unique word to each ingredient it appears in
# to ingredient itself plus the ingredient broken up into a list of words
#print ingredientwords

#do not run this unless needed! writing to workingingredients
inputingredientwords = ingredienttowords
output = open('workingingredients.pkl', 'wb')
pickle.dump(inputingredientwords, output)
output.close()

# read python dict back from the file
#pkl_file = open('workingingredients.pkl', 'rb')
#outputingredientwords = pickle.load(pkl_file)
#pkl_file.close()


#ingredientswords = outputingredientwords

#print("this was my original dictionary")
#print inputingredientwords
#print("this is my pkl dictionary")
#print outputingredientwords

'''
ingredientscounting={}

for key,value in ingredientwords.items():
    ingredientscounting[key]=(value, len(value))

print("ingredientscounting")
    
print ingredientscounting
    
#write the number of occurences into the file

'''

'''
numberofingredients={}

for key,value in ingredientwords.items():
    #print("This is how many ingredients contain this word")
    #print key, value[1] 
    numberofingredients[key]=value[1]
    
print('We know that there are %d unique words in the ingredients') % len(numberofingredients)

masteringredient=[]
rarewords =[]
insignificantwords=["Oven","it","Cuisine"]
words_appearing_twice_ormore = []

#now I want to assign a label to each word in the dictionary, as to whether it is significant

for key,value in numberofingredients.items():
    # assumes words that appear over a certain threshold to be insignificant, here 73 times
    if value >=73:
        insignificantwords.append(str(key))
        numberofingredients[key]=value,"very common"
    # marking all unique words that appear only once to be significant/rare
    if value<2:
        rarewords.append(str(key))
        numberofingredients[key]=value,"rare"
    elif value >=2 and value <73:
        words_appearing_twice_ormore.append(str(key))
        numberofingredients[key]=value,"medium frequency"
        
print("I have this many words that appear only once %d" % len(rarewords))
#print rarewords

print ingredientwords


print("I am processing the rare words to see whether they are verbs or numbers")

for word in rarewords:
    processed = pos_tag([word])
    print word, processed
    #split out the tag identifying the word type
    tag = ", ".join(t for w, t in processed)
    print(tag)
    if str(tag)=="CD" or str(tag)=="VBN" or str(tag)=="JJ":
        #including adjectives takes out words like Jamaican but gives us 125 stop words 
        def check(word, cuisines):
            if word in cuisines:
                print("The word is in the list!")
                print word
            else:
                print("The word is not in the list!")
                print word
                print("I found a number or verb or adjective which is not a cuisine")
                insignificantwords.append(word)

    
print("I have found %d insignificant words" % len(insignificantwords))
print("these are very common words and rare words that are numbers or verbs")
print insignificantwords


#Now look at the words that appear twice or more
for word in words_appearing_twice_ormore:
    processed = pos_tag([word])
    print word, processed
    #split out the tag identifying the word type
    tag = ", ".join(t for w, t in processed)
    print(tag)
    if str(tag)=="CD" or str(tag)=="VBN": 
    #or str(tag)=="JJ": including adjectives takes out words like Jamaican but gives us 125 stop words 
        print("I found a number or verb")
        insignificantwords.append(word)

print("I have found %d insignificant words" % len(insignificantwords))
print insignificantwords

'''

#unique word against ingredients it appears in
#df = pd.DataFrame(ingredientwords.items(), columns=['Ingredient', 'Ingredient words'])
#df

# number of times each unique word appears
'''
df2 = pd.DataFrame(numberofingredients.items(), 
              columns=['Ingredient word', 'Occurences']).sort_values(by=['Occurences'],ascending=False)
df2
'''
# Out:
# We are starting with 6714 unique ingredients
# here are all the cuisines
# ['Belgian', 'british\n', 'indian\n', 'italian\n', 'japanese\n', 'mexican\n', 'filipino\n', 'thai\n', 'irish\n', 'spanish\n', 'jamaican\n', 'greek\n', 'vietnamese\n', 'french\n', 'korean\n', 'chinese\n', 'moroccan\n', 'southern_us\n', 'russian\n', 'brazilian\n', 'cajun_creole']
# leg quarters
#
# ['leg', 'quarters']
# loin pork roast
#
# ['loin', 'pork', 'roast']
# verjuice
#
# ['verjuice']
# cardamon
#
# ['cardamon']
# rosewater
#
# ['rosewater']
# venison roast
#
# ['venison', 'roast']
# chop green chilies, undrain
#
# ['chop', 'green', 'chilies', 'undrain']
# light butter
#
# ['light', 'butter']
# kidney
#
# ['kidney']
# pork tenderloin
#
# ['pork', 'tenderloin']
# tart shells
#
# ['tart', 'shells']
# dry gin
#
# ['dry', 'gin']
# bass fillets
#
# ['bass', 'fillets']
# serrano
#
# ['serrano']
# organic milk
#
# ['organic', 'milk']
# casings
#
# ['casings']
# bread ciabatta
#
# ['bread', 'ciabatta']
# ...
